# %%
import pickle
import matplotlib.pyplot as plot
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pandas import DataFrame
from sklearn.gaussian_process.kernels import RBF
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import pickle
from gplearn.genetic import SymbolicRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.tree import export_graphviz
import pydotplus
import graphviz
from io import StringIO
from IPython.display import Image
import pandas as pd

# %%
dataset= r'TrainTest_3.csv'
data=pd.DataFrame(pd.read_csv(dataset))

# %%
# 获取空值的位置信息并打印
for i in range(len(data)):
    for j in range(len(data.columns)):
        if pd.isna(data.iloc[i, j]) or (pd.notna(data.iloc[i, j]) and str(data.iloc[i, j]).strip() == ''):
            print('第{}行、第{}列存在空值'.format(i+1, j+1))
# Out:
# 第1行、第73列存在空值
# 第2行、第73列存在空值
# 第3行、第73列存在空值
# 第4行、第73列存在空值
# 第5行、第73列存在空值
# 第6行、第73列存在空值
# 第7行、第73列存在空值
# 第8行、第73列存在空值
# 第9行、第73列存在空值
# 第10行、第73列存在空值
# 第11行、第73列存在空值
# 第12行、第73列存在空值
# 第13行、第73列存在空值
# 第14行、第73列存在空值
# 第15行、第73列存在空值
# 第16行、第73列存在空值
# 第17行、第73列存在空值
# 第18行、第73列存在空值
# 第19行、第73列存在空值
# 第20行、第73列存在空值
# 第21行、第73列存在空值
# 第22行、第73列存在空值
# 第23行、第73列存在空值
# 第24行、第73列存在空值
# 第25行、第73列存在空值
# 第26行、第73列存在空值
# 第27行、第73列存在空值
# 第28行、第73列存在空值
# 第29行、第73列存在空值
# 第30行、第73列存在空值
# 第31行、第73列存在空值
# 第32行、第73列存在空值
# 第33行、第73列存在空值
# 第34行、第73列存在空值
# 第35行、第73列存在空值
# 第36行、第73列存在空值
# 第37行、第73列存在空值
# 第38行、第73列存在空值
# 第39行、第73列存在空值
# 第40行、第73列存在空值
# 第41行、第73列存在空值
# 第42行、第73列存在空值
# 第43行、第73列存在空值
# 第44行、第73列存在空值
# 第45行、第73列存在空值
# 第46行、第73列存在空值
# 第47行、第73列存在空值
# 第48行、第73列存在空值
# 第49行、第73列存在空值
# 第50行、第73列存在空值
# 第51行、第73列存在空值
# 第52行、第73列存在空值
# 第53行、第73列存在空值
# 第54行、第73列存在空值
# 第55行、第73列存在空值
# 第56行、第73列存在空值
# 第57行、第73列存在空值
# 第58行、第73列存在空值
# 第59行、第73列存在空值
# 第60行、第73列存在空值
# 第61行、第73列存在空值
# 第62行、第73列存在空值
# 第63行、第73列存在空值
# 第64行、第73列存在空值
# 第65行、第73列存在空值
# 第66行、第73列存在空值
# 第67行、第73列存在空值
# 第68行、第73列存在空值
# 第69行、第73列存在空值
# 第70行、第73列存在空值
# 第71行、第73列存在空值
# 第72行、第73列存在空值
# 第73行、第73列存在空值
# 第74行、第73列存在空值
# 第75行、第73列存在空值
# 第76行、第73列存在空值
# 第77行、第73列存在空值
# 第78行、第73列存在空值
# 第79行、第73列存在空值
# 第80行、第73列存在空值
# 第81行、第73列存在空值
# 第82行、第73列存在空值
# 第83行、第73列存在空值
# 第84行、第73列存在空值
# 第85行、第73列存在空值
# 第86行、第73列存在空值
# 第87行、第73列存在空值
# 第88行、第73列存在空值
# 第89行、第73列存在空值
# 第90行、第73列存在空值
# 第91行、第73列存在空值
# 第92行、第73列存在空值
# 第93行、第73列存在空值
# 第94行、第73列存在空值
# 第95行、第73列存在空值
# 第96行、第73列存在空值
# 第97行、第73列存在空值
# 第98行、第73列存在空值
# 第99行、第73列存在空值
# 第100行、第73列存在空值
# 第101行、第73列存在空值
# 第102行、第73列存在空值
# 第103行、第73列存在空值
# 第104行、第73列存在空值
# 第105行、第73列存在空值
# 第106行、第73列存在空值
# 第107行、第73列存在空值
# 第108行、第73列存在空值
# 第109行、第73列存在空值
# 第110行、第73列存在空值
# 第111行、第73列存在空值
# 第112行、第73列存在空值
# 第113行、第73列存在空值
# 第114行、第73列存在空值
# 第115行、第73列存在空值
# 第116行、第73列存在空值
# 第117行、第73列存在空值
# 第118行、第73列存在空值
# 第119行、第73列存在空值
# 第120行、第73列存在空值
# 第121行、第73列存在空值
# 第122行、第73列存在空值
# 第123行、第73列存在空值
# 第124行、第73列存在空值
# 第125行、第73列存在空值
# 第126行、第73列存在空值
# 第127行、第73列存在空值
# 第128行、第73列存在空值
# 第129行、第73列存在空值
# 第130行、第73列存在空值
# 第131行、第73列存在空值
# 第132行、第73列存在空值
# 第133行、第73列存在空值
# 第134行、第73列存在空值
# 第135行、第73列存在空值
# 第136行、第73列存在空值
# 第137行、第73列存在空值
# 第138行、第73列存在空值
# 第139行、第73列存在空值
# 第140行、第73列存在空值
# 第141行、第73列存在空值
# 第142行、第73列存在空值
# 第143行、第73列存在空值
# 第144行、第73列存在空值
# 第145行、第73列存在空值
# 第146行、第73列存在空值
# 第147行、第73列存在空值
# 第148行、第73列存在空值
# 第149行、第73列存在空值
# 第150行、第73列存在空值
# 第151行、第73列存在空值
# 第152行、第73列存在空值
# 第153行、第73列存在空值
# 第154行、第73列存在空值
# 第155行、第73列存在空值
# 第156行、第73列存在空值
# 第157行、第73列存在空值
# 第158行、第73列存在空值
# 第159行、第73列存在空值
# 第160行、第73列存在空值
# 第161行、第73列存在空值
# 第162行、第73列存在空值
# 第163行、第73列存在空值
# 第164行、第73列存在空值
# 第165行、第73列存在空值
# 第166行、第73列存在空值
# 第167行、第73列存在空值
# 第168行、第73列存在空值
# 第169行、第73列存在空值
# 第170行、第73列存在空值
# 第171行、第73列存在空值
# 第172行、第73列存在空值
# 第173行、第73列存在空值
# 第174行、第73列存在空值
# 第175行、第73列存在空值
# 第176行、第73列存在空值
# 第177行、第73列存在空值
# 第178行、第73列存在空值
# 第179行、第73列存在空值
# 第180行、第73列存在空值
# 第181行、第73列存在空值
# 第182行、第73列存在空值
# 第183行、第73列存在空值
# 第184行、第73列存在空值
# 第185行、第73列存在空值
# 第186行、第73列存在空值
# 第187行、第73列存在空值
# 第188行、第73列存在空值
# 第189行、第73列存在空值
# 第190行、第73列存在空值
# 第191行、第73列存在空值
# 第192行、第73列存在空值
# 第193行、第73列存在空值
# 第194行、第73列存在空值
# 第195行、第73列存在空值
# 第196行、第73列存在空值
# 第197行、第73列存在空值
# 第198行、第73列存在空值
# 第199行、第73列存在空值
# 第200行、第73列存在空值
# 第201行、第73列存在空值
# 第202行、第73列存在空值
# 第203行、第73列存在空值
# 第204行、第73列存在空值
# 第205行、第73列存在空值
# 第206行、第73列存在空值
# 第207行、第73列存在空值
# 第208行、第73列存在空值
# 第209行、第73列存在空值
# 第210行、第73列存在空值
# 第211行、第73列存在空值
# 第212行、第73列存在空值
# 第213行、第73列存在空值
# 第214行、第73列存在空值
# 第215行、第73列存在空值
# 第216行、第73列存在空值
# 第217行、第73列存在空值
# 第218行、第73列存在空值
# 第219行、第73列存在空值
# 第220行、第73列存在空值
# 第221行、第73列存在空值
# 第222行、第73列存在空值
# 第223行、第73列存在空值
# 第224行、第73列存在空值
# 第225行、第73列存在空值
# 第226行、第73列存在空值
# 第227行、第73列存在空值
# 第228行、第73列存在空值
# 第229行、第73列存在空值
# 第230行、第73列存在空值
# 第231行、第73列存在空值
# 第232行、第73列存在空值
# 第233行、第73列存在空值
# 第234行、第73列存在空值
# 第235行、第73列存在空值
# 第236行、第73列存在空值
# 第237行、第73列存在空值
# 第238行、第73列存在空值
# 第239行、第73列存在空值
# 第240行、第73列存在空值
# 第241行、第73列存在空值
# 第242行、第73列存在空值
# 第243行、第73列存在空值
# 第244行、第73列存在空值
# 第245行、第73列存在空值
# 第246行、第73列存在空值
# 第247行、第73列存在空值
# 第248行、第73列存在空值
# 第249行、第73列存在空值
# 第250行、第73列存在空值
# 第251行、第73列存在空值
# 第252行、第73列存在空值
# 第253行、第73列存在空值
# 第254行、第73列存在空值
# 第255行、第73列存在空值
# 第256行、第73列存在空值
# 第257行、第73列存在空值
# 第258行、第73列存在空值
# 第259行、第73列存在空值
# 第260行、第73列存在空值
# 第261行、第73列存在空值
# 第262行、第73列存在空值
# 第263行、第73列存在空值
# 第264行、第73列存在空值
# 第265行、第73列存在空值
# 第266行、第73列存在空值
# 第267行、第73列存在空值
# 第268行、第73列存在空值
# 第269行、第73列存在空值
# 第270行、第73列存在空值
# 第271行、第73列存在空值
# 第272行、第73列存在空值
# 第273行、第73列存在空值
# 第274行、第73列存在空值
# 第275行、第73列存在空值
# 第276行、第73列存在空值
# 第277行、第73列存在空值
# 第278行、第73列存在空值
# 第279行、第73列存在空值
# 第280行、第73列存在空值
# 第281行、第73列存在空值
# 第282行、第73列存在空值
# 第283行、第73列存在空值
# 第284行、第73列存在空值
# 第285行、第73列存在空值
# 第286行、第73列存在空值
# 第287行、第73列存在空值
# 第288行、第73列存在空值
# 第289行、第73列存在空值
# 第290行、第73列存在空值
# 第291行、第73列存在空值
# 第292行、第73列存在空值
# 第293行、第73列存在空值
# 第294行、第73列存在空值
# 第295行、第73列存在空值
# 第296行、第73列存在空值
# 第297行、第73列存在空值
# 第298行、第73列存在空值
# 第299行、第73列存在空值
# 第300行、第73列存在空值
# 第301行、第73列存在空值
# 第302行、第73列存在空值
# 第303行、第73列存在空值
# 第304行、第73列存在空值
# 第305行、第73列存在空值
# 第306行、第73列存在空值
# 第307行、第73列存在空值
# 第308行、第73列存在空值
# 第309行、第73列存在空值
# 第310行、第73列存在空值
# 第311行、第73列存在空值
# 第312行、第73列存在空值
# 第313行、第73列存在空值
# 第314行、第73列存在空值
# 第315行、第73列存在空值
# 第316行、第73列存在空值
# 第317行、第73列存在空值
# 第318行、第73列存在空值
# 第319行、第73列存在空值
# 第320行、第73列存在空值
# 第321行、第73列存在空值
# 第322行、第73列存在空值
# 第323行、第73列存在空值
# 第324行、第73列存在空值
# 第325行、第73列存在空值
# 第326行、第73列存在空值
# 第327行、第73列存在空值
# 第328行、第73列存在空值
# 第329行、第73列存在空值
# 第330行、第73列存在空值
# 第331行、第73列存在空值
# 第332行、第73列存在空值
# 第333行、第73列存在空值
# 第334行、第73列存在空值
# 第335行、第73列存在空值
# 第336行、第73列存在空值
# 第337行、第73列存在空值
# 第338行、第73列存在空值
# 第339行、第73列存在空值
# 第340行、第73列存在空值
# 第341行、第73列存在空值
# 第342行、第73列存在空值
# 第343行、第73列存在空值
# 第344行、第73列存在空值
# 第345行、第73列存在空值
# 第346行、第73列存在空值
# 第347行、第73列存在空值
# 第348行、第73列存在空值
# 第349行、第73列存在空值
# 第350行、第73列存在空值
# 第351行、第73列存在空值
# 第352行、第73列存在空值
# 第353行、第73列存在空值
# 第354行、第73列存在空值
# 第355行、第73列存在空值
# 第356行、第73列存在空值
# 第357行、第73列存在空值
# 第358行、第73列存在空值
# 第359行、第73列存在空值
# 第360行、第73列存在空值
# 第361行、第73列存在空值
# 第362行、第73列存在空值
# 第363行、第73列存在空值
# 第364行、第73列存在空值
# 第365行、第73列存在空值
# 第366行、第73列存在空值
# 第367行、第73列存在空值
# 第368行、第73列存在空值
# 第369行、第73列存在空值
# 第370行、第73列存在空值
# 第371行、第73列存在空值
# 第372行、第73列存在空值
# 第373行、第73列存在空值
# 第374行、第73列存在空值
# 第375行、第73列存在空值
# 第376行、第73列存在空值
# 第377行、第73列存在空值
# 第378行、第73列存在空值
# 第379行、第73列存在空值
# 第380行、第73列存在空值
# 第381行、第73列存在空值
# 第382行、第73列存在空值
# 第383行、第73列存在空值
# 第384行、第73列存在空值
# 第385行、第73列存在空值
# 第386行、第73列存在空值
# 第387行、第73列存在空值
# 第388行、第73列存在空值
# 第389行、第73列存在空值
# 第390行、第73列存在空值
# 第391行、第73列存在空值
# 第392行、第73列存在空值
# 第393行、第73列存在空值
# 第394行、第73列存在空值
# 第395行、第73列存在空值
# 第396行、第73列存在空值
# 第397行、第73列存在空值
# 第398行、第73列存在空值
# 第399行、第73列存在空值
# 第400行、第73列存在空值
# 第401行、第73列存在空值
# 第402行、第73列存在空值
# 第403行、第73列存在空值
# 第404行、第73列存在空值
# 第405行、第73列存在空值
# 第406行、第73列存在空值
# 第407行、第73列存在空值
# 第408行、第73列存在空值
# 第409行、第73列存在空值
# 第410行、第73列存在空值
# 第411行、第73列存在空值
# 第412行、第73列存在空值
# 第413行、第73列存在空值
# 第414行、第73列存在空值
# 第415行、第73列存在空值
# 第416行、第73列存在空值
# 第417行、第73列存在空值
# 第418行、第73列存在空值
# 第419行、第73列存在空值
# 第420行、第73列存在空值
# 第421行、第73列存在空值
# 第422行、第73列存在空值
# 第423行、第73列存在空值
# 第424行、第73列存在空值
# 第425行、第73列存在空值
# 第426行、第73列存在空值
# 第427行、第73列存在空值
# 第428行、第73列存在空值
# 第429行、第73列存在空值
# 第430行、第73列存在空值
# 第431行、第73列存在空值
# 第432行、第73列存在空值
# 第433行、第73列存在空值
# 第434行、第73列存在空值
# 第435行、第73列存在空值
# 第436行、第73列存在空值
# 第437行、第73列存在空值
# 第438行、第73列存在空值
# 第439行、第73列存在空值
# 第440行、第73列存在空值
# 第441行、第73列存在空值
# 第442行、第73列存在空值
# 第443行、第73列存在空值
# 第444行、第73列存在空值
# 第445行、第73列存在空值
# 第446行、第73列存在空值
# 第447行、第73列存在空值
# 第448行、第73列存在空值
# 第449行、第73列存在空值
# 第450行、第73列存在空值
# 第451行、第73列存在空值
# 第452行、第73列存在空值
# 第453行、第73列存在空值
# 第454行、第73列存在空值
# 第455行、第73列存在空值
# 第456行、第73列存在空值
# 第457行、第73列存在空值
# 第458行、第73列存在空值
# 第459行、第73列存在空值
# 第460行、第73列存在空值
# 第461行、第73列存在空值
# 第462行、第73列存在空值
# 第463行、第73列存在空值
# 第464行、第73列存在空值
# 第465行、第73列存在空值
# 第466行、第73列存在空值
# 第467行、第73列存在空值
# 第468行、第73列存在空值
# 第469行、第73列存在空值
# 第470行、第73列存在空值
# 第471行、第73列存在空值
# 第472行、第73列存在空值
# 第473行、第73列存在空值
# 第474行、第73列存在空值
# 第475行、第73列存在空值
# 第476行、第73列存在空值
# 第477行、第73列存在空值
# 第478行、第73列存在空值
# 第479行、第73列存在空值
# 第480行、第73列存在空值
# 第481行、第73列存在空值
# 第482行、第73列存在空值
# 第483行、第73列存在空值
# 第484行、第73列存在空值
# 第485行、第73列存在空值
# 第486行、第73列存在空值
# 第487行、第73列存在空值
# 第488行、第73列存在空值
# 第489行、第73列存在空值
# 第490行、第73列存在空值
# 第491行、第73列存在空值
# 第492行、第73列存在空值
# 第493行、第73列存在空值
# 第494行、第73列存在空值
# 第495行、第73列存在空值
# 第496行、第73列存在空值
# 第497行、第73列存在空值
# 第498行、第73列存在空值
# 第499行、第73列存在空值
# 第500行、第73列存在空值
# 第501行、第73列存在空值
# 第502行、第73列存在空值
# 第503行、第73列存在空值
# 第504行、第73列存在空值
# 第505行、第73列存在空值
# 第506行、第73列存在空值
# 第507行、第73列存在空值
# 第508行、第73列存在空值
# 第509行、第73列存在空值
# 第510行、第73列存在空值
# 第511行、第73列存在空值
# 第512行、第73列存在空值
# 第513行、第73列存在空值
# 第514行、第73列存在空值
# 第515行、第73列存在空值
# 第516行、第73列存在空值
# 第517行、第73列存在空值
# 第518行、第73列存在空值
# 第519行、第73列存在空值
# 第520行、第73列存在空值
# 第521行、第73列存在空值
# 第522行、第73列存在空值
# 第523行、第73列存在空值
# 第524行、第73列存在空值
# 第525行、第73列存在空值
# 第526行、第73列存在空值
# 第527行、第73列存在空值
# 第528行、第73列存在空值
# 第529行、第73列存在空值
# 第530行、第73列存在空值
# 第531行、第73列存在空值
# 第532行、第73列存在空值
# 第533行、第73列存在空值
# 第534行、第73列存在空值
# 第535行、第73列存在空值
# 第536行、第73列存在空值
# 第537行、第73列存在空值
# 第538行、第73列存在空值
# 第539行、第73列存在空值
# 第540行、第73列存在空值
# 第541行、第73列存在空值
# 第542行、第73列存在空值
# 第543行、第73列存在空值
# 第544行、第73列存在空值
# 第545行、第73列存在空值
# 第546行、第73列存在空值
# 第547行、第73列存在空值
# 第548行、第73列存在空值
# 第549行、第73列存在空值
# 第550行、第73列存在空值
# 第551行、第73列存在空值
# 第552行、第73列存在空值
# 第553行、第73列存在空值
# 第554行、第73列存在空值
# 第555行、第73列存在空值
# 第556行、第73列存在空值
# 第557行、第73列存在空值
# 第558行、第73列存在空值
# 第559行、第73列存在空值
# 第560行、第73列存在空值
# 第561行、第73列存在空值
# 第562行、第73列存在空值
# 第563行、第73列存在空值
# 第564行、第73列存在空值
# 第565行、第73列存在空值
# 第566行、第73列存在空值
# 第567行、第73列存在空值
# 第568行、第73列存在空值
# 第569行、第73列存在空值
# 第570行、第73列存在空值
# 第571行、第73列存在空值
# 第572行、第73列存在空值
# 第573行、第73列存在空值
# 第574行、第73列存在空值
# 第575行、第73列存在空值
# 第576行、第73列存在空值
# 第577行、第73列存在空值
# 第578行、第73列存在空值
# 第579行、第73列存在空值
# 第580行、第73列存在空值
# 第581行、第73列存在空值
# 第582行、第73列存在空值
# 第583行、第73列存在空值
# 第584行、第73列存在空值
# 第585行、第73列存在空值
# 第586行、第73列存在空值
# 第587行、第73列存在空值
# 第588行、第73列存在空值
# 第589行、第73列存在空值
# 第590行、第73列存在空值
# 第591行、第73列存在空值
# 第592行、第73列存在空值
# 第593行、第73列存在空值
# 第594行、第73列存在空值
# 第595行、第73列存在空值
# 第596行、第73列存在空值
# 第597行、第73列存在空值
# 第598行、第73列存在空值
# 第599行、第73列存在空值
# 第600行、第73列存在空值
# 第601行、第73列存在空值
# 第602行、第73列存在空值
# 第603行、第73列存在空值
# 第604行、第73列存在空值
# 第605行、第73列存在空值
# 第606行、第73列存在空值
# 第607行、第73列存在空值
# 第608行、第73列存在空值
# 第609行、第73列存在空值
# 第610行、第73列存在空值
# 第611行、第73列存在空值
# 第612行、第73列存在空值
# 第613行、第73列存在空值
# 第614行、第73列存在空值
# 第615行、第73列存在空值
# 第616行、第73列存在空值
# 第617行、第73列存在空值
# 第618行、第73列存在空值
# 第619行、第73列存在空值
# 第620行、第73列存在空值
# 第621行、第73列存在空值
# 第622行、第73列存在空值
# 第623行、第73列存在空值
# 第624行、第73列存在空值
# 第625行、第73列存在空值
# 第626行、第73列存在空值
# 第627行、第73列存在空值
# 第628行、第73列存在空值
# 第629行、第73列存在空值
# 第630行、第73列存在空值
# 第631行、第73列存在空值
# 第632行、第73列存在空值
# 第633行、第73列存在空值
# 第634行、第73列存在空值
# 第635行、第73列存在空值
# 第636行、第73列存在空值
# 第637行、第73列存在空值
# 第638行、第73列存在空值
# 第639行、第73列存在空值
# 第640行、第73列存在空值

# %%
dataset= r'TrainTest_3.csv'
data=pd.DataFrame(pd.read_csv(dataset))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_Data=data.iloc[:,:]
global corMat
corMat = pd.DataFrame(all_Data.corr())  #corr 求相关系数矩阵
corMat.to_csv('./outputs_Elemental+OneHot/heatmap-before.csv')
plt.figure(figsize=(20, 30))
sns.heatmap(corMat, annot=False, vmax=1, square=True, cmap="Blues",linewidths=0)
plt.savefig('./outputs_Elemental+OneHot/heatmap-before.png', dpi=300, bbox_inches = 'tight')
plt.close()

# %%
# 使用随机森林的rfe:RandomForestRegressor()
from sklearn import preprocessing
from sklearn.feature_selection import RFE, RFECV
from sklearn.ensemble import RandomForestRegressor
import csv
import numpy as np

# 输入数据归一化
X = data.values[:, :-1]
for i in range(X.shape[1]):
    X[:, [i]] = preprocessing.MinMaxScaler().fit_transform(X[:, [i]])
y = data.values[:, -1]  # 目标数值

# rfe步骤
remain_number = 20
model = RandomForestRegressor()
rfe = RFE(estimator=model, n_features_to_select=remain_number, step=1)
rfe_X = rfe.fit_transform(X, y)
print("Whether features are selected：\n", rfe.support_)                                          # ndarray
print("Feature size:", rfe_X.shape)                                           # tuple
list1 = rfe.support_.tolist()

# 打印rfe后的特征，但可能包含空值
import pandas as pd
Features_0 = pd.DataFrame(data=data.iloc[:, :-1].columns, columns=['Features'])
Features_0
Features_rfe = pd.DataFrame(data=rfe.support_, columns=['whether selected'])
Features_rfe
#     pd.options.display.max_rows=None
p = pd.concat([Features_0, Features_rfe], axis=1)
q = p[p['whether selected']>0]
r = q.reset_index(drop=True)
global s_rfe
s_rfe = pd.DataFrame(data=data,columns=r.Features.values)
global target
target = pd.DataFrame(data=data.iloc[:,-1])
# target = pd.DataFrame(data, columns=['Potential (v)'])
global data_rfe
data_rfe = pd.concat([s_rfe,target], axis=1)
print("Final features (s_rfe):", r.Features.values)                                        # ndarray
print("target:", target)
print("data after rfe feature selection (data_rfe):", data_rfe)

list2 = r.Features.values.tolist()

# print全输出
with open("data.txt", "w") as f:
    #f.write("特征是否被选中：\n")
    f.write("Whether the feature is selected:\n")
    for i in range(len(list1)):
        f.write(str(list1[i])+' ')
    #f.write("\n获取的数据特征尺寸：\n")
    f.write("\nAcquired data feature size:\n")
    f.write('(%s,%s)' % rfe_X.shape)
    #f.write("\n最后的特征s_rfe：\n")
    f.write("\nS_rfe(Final feature)：\n")
    for i in range(len(list2)):
        f.write(str(list2[i]) + '\n')
target.to_csv("target.csv")
data_rfe.to_csv("data_rfe.csv")

# %%
data_rfe
# Out:
#      MagpieData mean Number  MagpieData mean MendeleevNumber  \
# 0                 10.571429                        64.714286
# 1                 10.571429                        64.714286
# 2                 10.571429                        64.714286
# 3                 10.571429                        64.714286
# 4                 10.571429                        64.714286
# ..                      ...                              ...
# 635               37.714286                        66.857143
# 636               37.714286                        66.857143
# 637               37.714286                        66.857143
# 638               37.714286                        66.857143
# 639               37.714286                        66.857143
#
#      MagpieData mean AtomicWeight  MagpieData mean MeltingT  \
# 0                       23.216516                333.254286
# 1                       23.216516                333.254286
# 2                       23.216516                333.254286
# 3                       23.216516                333.254286
# 4                       23.216516                333.254286
# ..                            ...                       ...
# 635                     87.765791                320.985714
# 636                     87.765791                320.985714
# 637                     87.765791                320.985714
# 638                     87.765791                320.985714
# 639                     87.765791                320.985714
#
#      MagpieData mean Row  MagpieData mean CovalentRadius  \
# 0               2.285714                       86.285714
# 1               2.285714                       86.285714
# 2               2.285714                       86.285714
# 3               2.285714                       86.285714
# 4               2.285714                       86.285714
# ..                   ...                             ...
# 635             4.428571                      151.571429
# 636             4.428571                      151.571429
# 637             4.428571                      151.571429
# 638             4.428571                      151.571429
# 639             4.428571                      151.571429
#
#      MagpieData mean Electronegativity  MagpieData mean NfValence  \
# 0                             2.841429                          0
# 1                             2.841429                          0
# 2                             2.841429                          0
# 3                             2.841429                          0
# 4                             2.841429                          0
# ..                                 ...                        ...
# 635                           2.177143                          0
# 636                           2.177143                          0
# 637                           2.177143                          0
# 638                           2.177143                          0
# 639                           2.177143                          0
#
#      MagpieData mean NValence  MagpieData mean GSvolume_pa  ...  \
# 0                    6.285714                    13.574524  ...
# 1                    6.285714                    13.574524  ...
# 2                    6.285714                    13.574524  ...
# 3                    6.285714                    13.574524  ...
# 4                    6.285714                    13.574524  ...
# ..                        ...                          ...  ...
# 635                  9.142857                    49.965000  ...
# 636                  9.142857                    49.965000  ...
# 637                  9.142857                    49.965000  ...
# 638                  9.142857                    49.965000  ...
# 639                  9.142857                    49.965000  ...
#
#      MagpieData mean SpaceGroupNumber         2         8   10        16   18  \
# 0                          106.142857  0.285714  0.571429  0.0  0.000000  0.0
# 1                          106.142857  0.285714  0.571429  0.0  0.000000  0.0
# 2                          106.142857  0.285714  0.571429  0.0  0.000000  0.0
# 3                          106.142857  0.285714  0.571429  0.0  0.000000  0.0
# 4                          106.142857  0.285714  0.571429  0.0  0.000000  0.0
# ..                                ...       ...       ...  ...       ...  ...
# 635                        122.142857  0.000000  0.000000  0.0  0.285714  0.0
# 636                        122.142857  0.000000  0.000000  0.0  0.285714  0.0
# 637                        122.142857  0.000000  0.000000  0.0  0.285714  0.0
# 638                        122.142857  0.000000  0.000000  0.0  0.285714  0.0
# 639                        122.142857  0.000000  0.000000  0.0  0.285714  0.0
#
#       34        36        49  Adsorption energy(ev)
# 0    0.0  0.000000  0.000000              -7.004905
# 1    0.0  0.000000  0.000000               0.395232
# 2    0.0  0.000000  0.000000              -6.580689
# 3    0.0  0.000000  0.000000              -5.557395
# 4    0.0  0.000000  0.000000               2.608437
# ..   ...       ...       ...                    ...
# 635  0.0  0.285714  0.142857              -1.934356
# 636  0.0  0.285714  0.142857              -0.151069
# 637  0.0  0.285714  0.142857              -4.757395
# 638  0.0  0.285714  0.142857              -0.462000
# 639  0.0  0.285714  0.142857              -4.003943
#
# [640 rows x 21 columns]

# %%
s_rfe
# Out:
#      MagpieData mean Number  MagpieData mean MendeleevNumber  \
# 0                 10.571429                        64.714286
# 1                 10.571429                        64.714286
# 2                 10.571429                        64.714286
# 3                 10.571429                        64.714286
# 4                 10.571429                        64.714286
# ..                      ...                              ...
# 635               37.714286                        66.857143
# 636               37.714286                        66.857143
# 637               37.714286                        66.857143
# 638               37.714286                        66.857143
# 639               37.714286                        66.857143
#
#      MagpieData mean AtomicWeight  MagpieData mean MeltingT  \
# 0                       23.216516                333.254286
# 1                       23.216516                333.254286
# 2                       23.216516                333.254286
# 3                       23.216516                333.254286
# 4                       23.216516                333.254286
# ..                            ...                       ...
# 635                     87.765791                320.985714
# 636                     87.765791                320.985714
# 637                     87.765791                320.985714
# 638                     87.765791                320.985714
# 639                     87.765791                320.985714
#
#      MagpieData mean Row  MagpieData mean CovalentRadius  \
# 0               2.285714                       86.285714
# 1               2.285714                       86.285714
# 2               2.285714                       86.285714
# 3               2.285714                       86.285714
# 4               2.285714                       86.285714
# ..                   ...                             ...
# 635             4.428571                      151.571429
# 636             4.428571                      151.571429
# 637             4.428571                      151.571429
# 638             4.428571                      151.571429
# 639             4.428571                      151.571429
#
#      MagpieData mean Electronegativity  MagpieData mean NfValence  \
# 0                             2.841429                          0
# 1                             2.841429                          0
# 2                             2.841429                          0
# 3                             2.841429                          0
# 4                             2.841429                          0
# ..                                 ...                        ...
# 635                           2.177143                          0
# 636                           2.177143                          0
# 637                           2.177143                          0
# 638                           2.177143                          0
# 639                           2.177143                          0
#
#      MagpieData mean NValence  MagpieData mean GSvolume_pa  \
# 0                    6.285714                    13.574524
# 1                    6.285714                    13.574524
# 2                    6.285714                    13.574524
# 3                    6.285714                    13.574524
# 4                    6.285714                    13.574524
# ..                        ...                          ...
# 635                  9.142857                    49.965000
# 636                  9.142857                    49.965000
# 637                  9.142857                    49.965000
# 638                  9.142857                    49.965000
# 639                  9.142857                    49.965000
#
#      MagpieData mean GSbandgap  MagpieData mean SpaceGroupNumber         2  \
# 0                     1.180429                        106.142857  0.285714
# 1                     1.180429                        106.142857  0.285714
# 2                     1.180429                        106.142857  0.285714
# 3                     1.180429                        106.142857  0.285714
# 4                     1.180429                        106.142857  0.285714
# ..                         ...                               ...       ...
# 635                   1.015714                        122.142857  0.000000
# 636                   1.015714                        122.142857  0.000000
# 637                   1.015714                        122.142857  0.000000
# 638                   1.015714                        122.142857  0.000000
# 639                   1.015714                        122.142857  0.000000
#
#             8   10        16   18   34        36        49
# 0    0.571429  0.0  0.000000  0.0  0.0  0.000000  0.000000
# 1    0.571429  0.0  0.000000  0.0  0.0  0.000000  0.000000
# 2    0.571429  0.0  0.000000  0.0  0.0  0.000000  0.000000
# 3    0.571429  0.0  0.000000  0.0  0.0  0.000000  0.000000
# 4    0.571429  0.0  0.000000  0.0  0.0  0.000000  0.000000
# ..        ...  ...       ...  ...  ...       ...       ...
# 635  0.000000  0.0  0.285714  0.0  0.0  0.285714  0.142857
# 636  0.000000  0.0  0.285714  0.0  0.0  0.285714  0.142857
# 637  0.000000  0.0  0.285714  0.0  0.0  0.285714  0.142857
# 638  0.000000  0.0  0.285714  0.0  0.0  0.285714  0.142857
# 639  0.000000  0.0  0.285714  0.0  0.0  0.285714  0.142857
#
# [640 rows x 20 columns]

# %%
target
# Out:
#      Adsorption energy(ev)
# 0                -7.004905
# 1                 0.395232
# 2                -6.580689
# 3                -5.557395
# 4                 2.608437
# ..                     ...
# 635              -1.934356
# 636              -0.151069
# 637              -4.757395
# 638              -0.462000
# 639              -4.003943
#
# [640 rows x 1 columns]

# %%
X = data_rfe.values[:, :-1]
y = data_rfe.values[:, -1]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=1)


for i in range(X_train.shape[1]):
    X_train[:, [i]] = preprocessing.MinMaxScaler().fit_transform(X_train[:, [i]])



for i in range(X_test.shape[1]):
    X_test[:, [i]] = preprocessing.MinMaxScaler().fit_transform(X_test[:, [i]])

# %%
feature_names = list(data_rfe.columns[:-1])

# %%
# 定义符号回归模型，并使用训练数据拟合模型
reg = SymbolicRegressor(population_size=5000, generations=20, verbose=1,
                         function_set=['add', 'sub', 'mul', 'div', 'sqrt', 'log', 'abs', 'neg', 
                                       'inv', 'max', 'min', 'sin', 'cos', 'tan'],
                         metric='mean absolute error', stopping_criteria=0.001,
                         random_state=0)
reg.fit(X_train, y_train)
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.67          4.18856       25          2.40859              N/A     55.66s
#    1     8.80          3.08714       23           2.3728              N/A      1.02m
#    2    13.05          3.04551       20          2.36021              N/A      1.10m
#    3    15.33          3.32262       20          2.34929              N/A      1.05m
#    4    14.65          9.02175       20          2.34929              N/A      1.04m
#    5     6.97          3.02458       28          2.34714              N/A     54.36s
#    6     6.03          3.38304       21          2.34246              N/A     51.62s
#    7     9.80          5.05056       14          2.33738              N/A     56.62s
#    8    12.61          3.87647       23          2.33651              N/A     52.88s
#    9    15.50          4.43322       20          2.33477              N/A     51.61s
#   10    16.40          3.79804       38          2.33284              N/A     49.20s
#   11    16.63          3.18126       27          2.33028              N/A     47.03s
#   12    16.71          3.55693       22          2.32774              N/A     48.90s
#   13    15.96          3.66852       32          2.32739              N/A     42.73s
#   14    15.65          3.02725       27          2.32747              N/A     42.44s
#   15    16.74          2.90678       18          2.32541              N/A     40.92s
#   16    17.07          2.70562       18          2.32538              N/A     39.82s
#   17    16.97          2.75415       23          2.32271              N/A     37.89s
#   18    16.61           2.8215       22          2.32232              N/A     37.50s
#   19    16.49          2.77203       22          2.32232              N/A     33.65s
#   20    16.21          2.98248       22          2.31858              N/A     31.95s
#   21    16.05          3.00532       21          2.31633              N/A     29.97s
#   22    16.25          2.81726       19          2.31622              N/A     28.22s
#   23    16.42          2.67472       22          2.31272              N/A     29.16s
#   24    16.68          2.62017       22          2.31272              N/A     26.63s
#   25    16.96          2.75181       21          2.31082              N/A     25.10s
#   26    18.06           2.6151       21          2.30892              N/A     22.38s
#   27    19.27          2.67309       21          2.30796              N/A     21.11s
#   28    19.55          2.68296       23          2.30676              N/A     19.26s
#   29    19.86          2.57117       23          2.30676              N/A     18.67s
#   30    20.20          2.66502       25          2.30676              N/A     15.60s
#   31    20.63          2.67893       23          2.30676              N/A     14.04s
#   32    20.71          2.52508       23          2.30676              N/A     12.21s
#   33    20.44           2.5333       27          2.30676              N/A     10.39s
#   34    20.50          2.51758       22          2.30676              N/A      9.56s
#   35    20.90          2.54256       22          2.30676              N/A      7.38s
#   36    21.33          2.50544       22          2.30676              N/A      5.46s
#   37    21.68          2.53063       22          2.30676              N/A      3.66s
#   38    21.74          2.50922       25          2.30601              N/A      1.81s
#   39    21.89          2.50132       22          2.30676              N/A      0.00s
# SymbolicRegressor(function_set=['add', 'sub', 'mul', 'div', 'sqrt', 'log',
#                                 'abs', 'neg', 'inv', 'max', 'min', 'sin', 'cos',
#                                 'tan'],
#                   generations=40, population_size=5000, random_state=0,
#                   stopping_criteria=0.001, verbose=1)

# %%
from sklearn.metrics import mean_absolute_error
# 预测测试数据
y_pred = reg.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 2.556649412625394

# %%
print(X_test.shape[1])
# Out:
# 20

# %%
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import numpy as np

# Get feature-importance scores
result = permutation_importance(reg, X_test, y_test, n_repeats=10, random_state=0)

# Create a heatmap
fig, ax = plt.subplots(figsize=(12,8))
im = ax.imshow(result.importances_mean.reshape(1, -1), cmap='YlGnBu')

# Add colorbar
cbar = ax.figure.colorbar(im, ax=ax)

# Set tick labels
ax.set_xticks(np.arange(len(result.importances_mean)))
ax.set_xticklabels([f"Feature {i+1}" for i in range(len(result.importances_mean))])
ax.set_yticks([])

# Rotate tick labels
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Set plot title and show plot
ax.set_title("Feature Importance Scores")
plt.show()
# 这个代码会创建一个热力图，显示特征重要性分数。
# x轴显示特征编号，每个单元格的颜色表示该特征的重要性分数，颜色越亮，意味着该特征对该模型越重要。

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot(range(-5, 5), range(-5, 5), "r--")
plt.xlabel("True values")
plt.ylabel("Predictions")
plt.show()
# 这个代码会创建一个散点图，显示模型的预测值与真实值之间的关系。
# x轴是真实值，y轴是预测值。如果模型预测完全准确，则所有点都将落在红色虚线上方，红色虚线表示完美预测的情况

# %%
plt.scatter(y_pred, y_test - y_pred, alpha=0.5)
plt.hlines(y=0, xmin=-5, xmax=5, colors='r', linestyles='--')
plt.xlabel("Predictions")
plt.ylabel("Residuals")
plt.show()
# 这个代码将创建一个散点图，表示预测值和残差之间的关系。
# x轴是预测值，y轴是残差。如果模型的预测值能够准确地预测目标变量，残差应该随机分布在0附近。
